# %%
import numpy as np
for i in np.linspace(0.0,1.0,101):
    delta = np.random.uniform(0.000000000,0.000000001)
    i=i+delta
    print(i)
# Out:
# 7.965429868602329e-10
# 0.01000000018343479
# 0.020000000779691
# 0.03000000059685016
# 0.040000000445832753
# 0.05000000009997492
# 0.06000000045924889
# 0.07000000033370862
# 0.08000000014286682
# 0.09000000065088846
# 0.10000000005641159
# 0.11000000072199877
# 0.1200000009385527
# 0.13000000000077877
# 0.14000000099221158
# 0.1500000006174815
# 0.16000000061165318
# 0.1700000000070663
# 0.1800000000230624
# 0.19000000052477467
# 0.200000000399861
# 0.21000000004666566
# 0.22000000097375552
# 0.23000000023277134
# 0.24000000009060643
# 0.250000000618386
# 0.260000000382462
# 0.2700000009832309
# 0.28000000046676293
# 0.2900000008599404
# 0.3000000006803075
# 0.31000000045049925
# 0.32000000001326495
# 0.3300000009422018
# 0.3400000005632882
# 0.3500000003854165
# 0.3600000000159662
# 0.3700000002308938
# 0.3800000002410255
# 0.3900000006832635
# 0.4000000006099967
# 0.41000000083319493
# 0.42000000017336464
# 0.4300000003910606
# 0.4400000001822361
# 0.4500000007553614
# ...

# %%
# %run -i "COMPAS_SVM.py"
# Out:
# Loaded training data
# Attempting to enforce demographic parity...
# maximumAccuracy
# 0.6124872437146303
# {'Caucasian': 0.05, 'African-American': 0.09166666666666666, 'Hispanic': 0.03333333333333333, 'Other': 0.016666666666666666}
# maximumAccuracy
# 0.627423694220243
# {'Other': 0.03333333333333333, 'African-American': 0.13333333333333333, 'Caucasian': 0.09166666666666666, 'Hispanic': 0.041666666666666664}
# maximumAccuracy
# 0.62751646720475
# {'Other': 0.03333333333333333, 'African-American': 0.13333333333333333, 'Caucasian': 0.09166666666666666, 'Hispanic': 0.05}
# --------------------DEMOGRAPHIC PARITY RESULTS--------------------
#
# Probability of positive prediction for African-American: 0.6101895734597157
# Probability of positive prediction for Caucasian: 0.6058135958166718
# Probability of positive prediction for Hispanic: 0.6127886323268206
# Probability of positive prediction for Other: 0.5976331360946746
#
# Accuracy for African-American: 0.6217417061611374
# ...

# %%
import numpy as np
a = np.array([1,1,2,3,4,4,5])
b= np.unique(a)
print(b)
x = np.size(b)
print(x)
# Out:
# [1 2 3 4 5]
# 5
